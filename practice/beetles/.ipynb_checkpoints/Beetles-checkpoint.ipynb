# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from src.LoadDogs2 import create_training_data
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2022-09-01 16:55:31.382217: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nags205/root/build/lib
# 2022-09-01 16:55:31.382271: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Fit by some models, input data = 56*56

# %%
(train_images, train_labels), (test_images, test_labels) = create_training_data(IMG_SIZE = 56)
# Out:
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9

# %% [markdown]
# ## model1

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(56, 56, 3)))
model1.add(layers.Conv2D(64, (5, 5), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Dropout(0.1))
model1.add(layers.Conv2D(64, (5, 5), activation='relu'))
model1.add(layers.Conv2D(64, (5, 5), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))


model1.add(layers.Flatten())
model1.add(layers.Dense(64, activation='relu'))
model1.add(layers.Dense(4,activation='softmax'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 54, 54, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        51264
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 64)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        102464
#
#  conv2d_3 (Conv2D)           (None, 17, 17, 64)        102464
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 64)                262208
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 519,556
# Trainable params: 519,556
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-01 17:01:32.452539: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nags205/.local/lib/python3.8/site-packages/cv2/../../lib64:/home/nags205/root/build/lib
# 2022-09-01 17:01:32.452852: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-01 17:01:32.452913: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (NagS205): /proc/driver/nvidia/version does not exist
# 2022-09-01 17:01:32.453585: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model1.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 2022-09-01 17:01:32.564442: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1233163008 exceeds 10% of free system memory.
# 1025/1025 [==============================] - 285s 277ms/step - loss: 1.2998 - accuracy: 0.5523
# Epoch 2/5
# 1025/1025 [==============================] - 294s 286ms/step - loss: 0.6062 - accuracy: 0.6964
# Epoch 3/5
# 1025/1025 [==============================] - 311s 304ms/step - loss: 0.4955 - accuracy: 0.7604
# Epoch 4/5
# 1025/1025 [==============================] - 289s 282ms/step - loss: 0.4701 - accuracy: 0.7812
# Epoch 5/5
# 1025/1025 [==============================] - 292s 285ms/step - loss: 0.4036 - accuracy: 0.8165

# %%
test_loss, test_acc = model1.evaluate(test_images, test_labels)
# Out:
# 2022-09-01 17:26:03.572847: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 555711744 exceeds 10% of free system memory.
# 462/462 [==============================] - 25s 52ms/step - loss: 11.9121 - accuracy: 0.2208

# %% [markdown]
# # evaluation of models

# %%
class_names = ['dog', 'cat', 'rhinoceros', 'stag']

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img.astype('uint8'), cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color='blue'
    else:
        color='red'
        
    plt.xlabel("{}{:2.0f}%({})".format(class_names[predicted_label],
                                       100*np.max(predictions_array),
                                       class_names[true_label]),
                                       color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i]
    plt.grid(False)
    plt.xticks(range(4))
    plt.yticks([])
    thisplot = plt.bar(range(4), predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# ## model 1

# %%
probability_model1 = tf.keras.Sequential([model1,
                                         tf.keras.layers.Softmax()])
predictions1 = probability_model1.predict(test_images)
# Out:
#   1/462 [..............................] - ETA: 1:14
# 2022-09-01 17:26:31.543490: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 555711744 exceeds 10% of free system memory.
# 462/462 [==============================] - 23s 50ms/step

# %%
num_rows = 5
num_cols = 5
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))

batch_mask = np.random.choice(len(test_images), num_images)
img_batch = test_images[batch_mask]
label_batch = test_labels[batch_mask]
predictions_batch = predictions1[batch_mask]

for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions_batch[i], label_batch, img_batch)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions_batch[i], label_batch)
plt.tight_layout()
plt.show()
